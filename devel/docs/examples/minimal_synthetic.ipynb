# %% [markdown]
# [IPython Notebook](minimal_synthetic.ipynb) |  [Python Script](minimal_synthetic.py)

# %% [markdown]
# Minimal Example to Produce a Synthetic Light Curve
# ============================
#
# Setup
# -----------------------------

# %%
# %matplotlib inline

# %% [markdown]
# As always, let's do imports and initialize a logger and a new bundle.  See [Building a System](../tutorials/building_a_system.html) for more details.

# %%
import phoebe
from phoebe import u # units
import numpy as np
import matplotlib.pyplot as plt

logger = phoebe.logger(clevel='INFO')

b = phoebe.Bundle.default_binary()

# %% [markdown]
# Adding Datasets
# ------------------
#
# Now we'll create an empty lc dataset:

# %%
b.add_dataset('LC', time=np.linspace(0,3,201), dataset='mylc')
# Out:
# <ParameterSet: 17 parameters | methods: LC, LC_dep>

# %% [markdown]
# Running Compute
# ---------------------

# %% [markdown]
# Now we'll compute synthetics at the times provided using the default options

# %%
b.run_compute()
# Out:
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/mesh.py:1869: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   the_grid = cmarching.discretize(delta, maxpoints, *mesh_args)[:-2]
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/mesh.py:1869: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   the_grid = cmarching.discretize(delta, maxpoints, *mesh_args)[:-2]
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/mesh.py:1869: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   the_grid = cmarching.discretize(delta, maxpoints, *mesh_args)[:-2]
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/mesh.py:1869: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   the_grid = cmarching.discretize(delta, maxpoints, *mesh_args)[:-2]
# ...

# %% [markdown]
# Plotting
# --------------
#
# Now we can simply plot the resulting synthetic light curve.

# %%
axs, artists = b['mylc@model'].plot()

# %%
axs, artists = b['mylc@model'].plot(x='phase')
